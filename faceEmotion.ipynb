# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('tanmayxd.jpeg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace

# %%
prediction = DeepFace.analyze(img)
# Out:
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 1/1 [==============================] - 2s 2s/step
# Action: age:  25%|██▌       | 1/4 [00:08<00:24,  8.33s/it]
# 1/1 [==============================] - 2s 2s/step
# Action: gender:  50%|█████     | 2/4 [00:10<00:08,  4.47s/it]
# 1/1 [==============================] - 1s 559ms/step
# Action: race:  75%|███████▌  | 3/4 [00:10<00:02,  2.72s/it]
# 1/1 [==============================] - 1s 550ms/step
# Action: race: 100%|██████████| 4/4 [00:11<00:00,  2.84s/it]

# %%
prediction
# Out:
# {'emotion': {'angry': 0.7549287285655737,
#   'disgust': 2.738960631631926e-05,
#   'fear': 10.337159782648087,
#   'happy': 0.5026366095989943,
#   'sad': 6.724000722169876,
#   'surprise': 0.01617605157662183,
#   'neutral': 81.66506886482239},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 329, 'y': 252, 'w': 260, 'h': 260},
#  'age': 23,
#  'gender': 'Man',
#  'race': {'asian': 31.155654788017273,
#   'indian': 15.75024276971817,
#   'black': 14.03060108423233,
#   'white': 6.851910054683685,
#   'middle eastern': 5.199997127056122,
#   'latino hispanic': 27.01159417629242},
#  'dominant_race': 'asian'}

# %%
emotion = prediction['dominant_emotion']
race = prediction['dominant_race']

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(gray, 1.1, 4)

for(x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, emotion, (20, 60), font, 3, (255, 0, 0), 2, cv2.LINE_4)
cv2.putText(img, race, (20, 125), font, 2, (255, 0, 0), 2, cv2.LINE_4)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.imshow(img)
